# %% [markdown]
# 1. Основные цели и задачи проекта:
# Цель проекта:
# Научиться проводить статистический анализ данных
# Задачи:
# Научиться проводить первичный анализ данных, в котором студент должен выявить выпадающие и недостающие значения в данных
# Научиться заполнять недостающие данные и фильтровать выпадающие данные.
# Научиться  определять корреляции, тренды и факторы взаимного влияния значений в данных
# Проверить и закрепить пройденный материал: pandas, библиотеки математических операций и графической визуализации данных
# Научиться строить математические гипотезы и проверять их
# Научиться делать выводы о трендах и корреляциях для дальнейшего построения математической модели, дающей прогноз каких-либо событий
# 2. Краткая информация о данных
# Датасет содержал данные об учениках и их результатах экзамена по математике
# 3. Этапы работы над проектом.
# День 1, День 2, День 3 )))
# Делал по плану п.2.8. переписывать не стал.
#
#
#
#
# 4. ответы на вопросы саморефлексии:
#
# 41. Какова была ваша роль в команде?
# В команде не работали ни в одном проекте
# 42. Какой частью своей работы вы остались особенно довольны?
# Никакой. Сплошная саморефлексия
# 43. Что не получилось сделать так, как хотелось? Над чем ещё стоит поработать?
# Недостаточно практических заданий для закрепления материала. Необходимо подтянуть мат. статистику и синтаксис питона (пандас)
# 44. Что интересного и полезного вы узнали в этом модуле?
# Все было интересно и полезно.
# Модуль в целом полезный. только в нем много ошибок. Доступ в интернет есть не всегда, поэтому вопрос в чат задать проблематично, приходится искать ответы в литературе. Перечитывать пройденный материал на предмет пропущенной информации, но бывает, оказывается, что ошибка в самом материале. А время потрачено.
# 45. Что является вашим главным результатом при прохождении этого проекта?
# Знакомство с практическим применением мат статистики при анализе большого объема информации.
# 46. Какие навыки вы уже можете применить в текущей деятельности?
# Статистическая обработка результатов эксперимента. Распределение Стъюдента.
# Распределение Стъюдента
# 47. Планируете ли вы дополнительно изучать материалы по теме проекта?
# Планирую
